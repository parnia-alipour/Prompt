# %%
import getpass
import os

# %%
def set_env(var:str):
    if not os.environ.get(var):
        os.environ[var]=getpass.getpass(f"{var}:")
    set_env("OPENAI_API_KEY")

# %%
set_env("LANGSMITH_API_KEY")
os.environ["LANGGRAPH_TRACING_V2"]="true"
os.environ["LANGGRAPH_PROJECT"]="langgraph tutorial"
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 set_env("LANGSMITH_API_KEY")
#       2 os.environ["LANGGRAPH_TRACING_V2"]="true"
#       3 os.environ["LANGGRAPH_PROJECT"]="langgraph tutorial"
#
# Cell In[5], line 4, in set_env(var)
#       2 if not os.environ.get(var):
#       3     os.environ[var]=getpass.getpass(f"{var}:")
# ----> 4 set_env("OPENAI_API_KEY")
#
# Cell In[5], line 4, in set_env(var)
#       2 if not os.environ.get(var):
#       3     os.environ[var]=getpass.getpass(f"{var}:")
# ----> 4 set_env("OPENAI_API_KEY")
#
#     [... skipping similar frames: set_env at line 4 (2970 times)]
#
# Cell In[5], line 4, in set_env(var)
#       2 if not os.environ.get(var):
#       3     os.environ[var]=getpass.getpass(f"{var}:")
# ----> 4 set_env("OPENAI_API_KEY")
#
# Cell In[5], line 2, in set_env(var)
#       1 def set_env(var:str):
# ----> 2     if not os.environ.get(var):
#       3         os.environ[var]=getpass.getpass(f"{var}:")
#       4     set_env("OPENAI_API_KEY")
#
# File <frozen _collections_abc>:811, in get(self, key, default)
#
# File <frozen os>:714, in __getitem__(self, key)
#
# File <frozen os>:787, in encodekey(key)
#
# RecursionError: maximum recursion depth exceeded

# %%
from typing import Annotated
from typing_extensions import TypedDict

from langgraph.graph import  StateGraph
from langgraph.graph.message import add_messages


class State(TypedDict):
    message: Annotated[list,add_messages]
graph_builder = StateGraph(State)

# %%
from langchain_openai import ChatOpenAI

llm=ChatOpenAI (model="gpt_4o")
    def chatbot(state: State):
        return {"message": llm.invoke(state["message"])}



    graph_builder.add_node("chatbot", chatbot)
