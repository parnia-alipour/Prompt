# %%
from openai import OpenAI

# %%
model="gpt_4o-mini"
client="a"

# %%
history=[{"role":"user","content":"tell me a jock"}]

# %%
response=client.response.create(
    model=model,
    api_key=,
    input=history,
    store=False,
)
